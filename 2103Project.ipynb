# %%
library(knitr)
library(dplyr)
library(readxl)

# %%
data <- read.csv("card.csv")
summary(data)
# Out:
#       ï..              X1          X2              X3               X4
#  1      :    1   50000  : 3365   1  :11888   2      :14030   0       :   54
#  10     :    1   20000  : 1976   2  :18112   1      :10585   1       :13659
#  100    :    1   30000  : 1610   SEX:    1   3      : 4917   2       :15964
#  1000   :    1   80000  : 1567               5      :  280   3       :  323
#  10000  :    1   200000 : 1528               4      :  123   MARRIAGE:    1
#  10001  :    1   150000 : 1110               6      :   51
#  (Other):29995   (Other):18845               (Other):   15
#        X5              X6              X7              X8
#  29     : 1605   0      :14737   0      :15730   0      :15764
#  27     : 1477   -1     : 5686   -1     : 6050   -1     : 5938
#  28     : 1409   1      : 3688   2      : 3927   -2     : 4085
#  30     : 1395   -2     : 2759   -2     : 3782   2      : 3819
#  26     : 1256   2      : 2667   3      :  326   3      :  240
# ...
